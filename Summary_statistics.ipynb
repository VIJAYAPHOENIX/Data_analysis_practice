# %%
import numpy as np 
import pandas as pd
from pandas import Series,DataFrame

# %%
arr = np.array([[1,2,np.nan],[np.nan,3,4]])
arr
# Out:
# array([[ 1.,  2., nan],
#        [nan,  3.,  4.]])

# %%
dframe1 = DataFrame(arr,index=['A','B'],columns=['one','Two','Three'])
dframe1
# Out:
#    one  Two  Three
# A  1.0  2.0    NaN
# B  NaN  3.0    4.0

# %%
dframe1.sum()
# Out:
# one      1.0
# Two      5.0
# Three    4.0
# dtype: float64

# %%
dframe1.sum(axis=1)
# Out:
# A    3.0
# B    7.0
# dtype: float64

# %%
dframe1.min()
# Out:
# one      1.0
# Two      2.0
# Three    4.0
# dtype: float64

# %%
dframe1.idxmin()
# Out:
# one      A
# Two      A
# Three    B
# dtype: object

# %%
# for accumilation sum
dframe1.cumsum()
# Out:
#    one  Two  Three
# A  1.0  2.0    NaN
# B  NaN  5.0    4.0

# %%
dframe1.describe()
# Out:
#        one       Two  Three
# count  1.0  2.000000    1.0
# mean   1.0  2.500000    4.0
# std    NaN  0.707107    NaN
# min    1.0  2.000000    4.0
# 25%    1.0  2.250000    4.0
# 50%    1.0  2.500000    4.0
# 75%    1.0  2.750000    4.0
# max    1.0  3.000000    4.0

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('xGpuFNR1ME')
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/xGpuFNR1ME"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
YouTubeVideo('4EXNedimDMs')

# %%
import yfinance as yf

import datetime

# %%
prices = yf.download(['CVX','XOM','BP'],start =datetime.datetime(2010,1,1),end=datetime.datetime(2013,1,1))['Adj Close']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
prices.head()
# Out:
# Ticker                            BP        CVX        XOM
# Date
# 2010-01-04 00:00:00+00:00  26.887163  44.045544  39.594814
# 2010-01-05 00:00:00+00:00  27.078087  44.357536  39.749413
# 2010-01-06 00:00:00+00:00  27.219004  44.363079  40.092983
# 2010-01-07 00:00:00+00:00  27.209917  44.195961  39.967003
# 2010-01-08 00:00:00+00:00  27.273539  44.273956  39.806667

# %%
volume =yf.download(['CVX','XOM','BP'],start =datetime.datetime(2010,1,1),end=datetime.datetime(2013,1,1))['Volume']
# Out:
# [*********************100%***********************]  3 of 3 completed

# %%
volume.head()
# Out:
# Ticker                          BP       CVX       XOM
# Date
# 2010-01-04 00:00:00+00:00  3956100  10173800  27809100
# 2010-01-05 00:00:00+00:00  4109600  10593700  30174700
# 2010-01-06 00:00:00+00:00  6227900  11014600  35044700
# 2010-01-07 00:00:00+00:00  4431300   9626900  27192100
# 2010-01-08 00:00:00+00:00  3786100   5624300  24891800

# %%
rets = prices.pct_change()
rets.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
# correlation of the stocks
core= rets.corr()
core.plot()
# Out:
# <Axes: xlabel='Ticker'>

# %%
prices.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
volume.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
prices.describe().astype('int64')
# Out:
# Ticker   BP  CVX  XOM
# count   754  754  754
# mean     20   56   45
# std       2    9    6
# min      12   38   32
# 25%      19   46   39
# 50%      20   59   47
# 75%      21   63   51
# max      28   72   57

# %%
sns.heatmap(prices, annot=False, diag_names=False, cmap='coolwarm', square=True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 sns.heatmap(prices, annot=False, diag_names=False, cmap='coolwarm', square=True)
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:459, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     457 if square:
#     458     ax.set_aspect("equal")
# --> 459 plotter.plot(ax, cbar_ax, kwargs)
#     460 return ax
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:306, in _HeatMapper.plot(self, ax, cax, kws)
#     303     kws.setdefault("vmax", self.vmax)
#     305 # Draw the heatmap
# --> 306 mesh = ax.pcolormesh(self.plot_data, cmap=self.cmap, **kws)
#     308 # Set the axis limits
# ...
